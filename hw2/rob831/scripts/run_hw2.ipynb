# %% [markdown]
# ##Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**.

# %%
#@title mount your Google Drive
#@markdown Your work will be stored in a folder called `hw_16831` by default to prevent Colab instance timeouts from deleting your edits.

import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title set up mount symlink

DRIVE_PATH = '/content/gdrive/My\ Drive/hw_16831'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/hw_16831'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %%
#@title apt install requirements

#@markdown Run each section with Shift+Enter

#@markdown Double-click on section headers to show code.

# !apt update
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python3-opengl \
        ffmpeg > /dev/null 2>&1
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,361 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,905 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,759 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,737 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,538 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,749 kB]
# Get:21 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [45.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,070 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:27 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# Fetched 40.0 MB in 9s (4,511 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 246 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !python -m pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Collecting wheel
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.11/dist-packages (from wheel) (24.2)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.3 MB/s eta 0:00:00
# Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 91.2 MB/s eta 0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-26.0.1 setuptools-82.0.0 wheel-0.46.3

# %%
# !python --version
# Out:
# Python 3.11.13

# %%
#@title clone homework repo
#@markdown Note that this is the same codebase from homework 1,
#@markdown so you may need to move your old `hw_16831`
#@markdown folder in order to clone the repo again.

#@markdown **Don't delete your old work though!**
#@markdown You will need it for this assignment.

# %cd $SYM_PATH
# %cd 16831_hw/
# !git clone https://github.com/namanxkumar/16831_hw.git
# !git pull
# %cd hw2
# %pip install -r requirements.txt
# %pip install -e .
# Out:
# /content/gdrive/My Drive/hw_16831
# /content/gdrive/My Drive/hw_16831/16831_hw
# Already up to date.
# /content/gdrive/My Drive/hw_16831/16831_hw/hw2
# Collecting numpy==1.25.2 (from -r requirements.txt (line 1))
#   Downloading numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting mujoco==2.2.1 (from -r requirements.txt (line 2))
#   Downloading mujoco-2.2.1.tar.gz (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gym==0.25.1 (from gym[box2d]==0.25.1->-r requirements.txt (line 3))
#   Downloading gym-0.25.1.tar.gz (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.2/732.2 kB 36.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensorboard==2.10.0 (from -r requirements.txt (line 5))
#   Downloading tensorboard-2.10.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorboardX==2.5.1 (from -r requirements.txt (line 6))
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==1.12.1
# Obtaining file:///content/gdrive/MyDrive/hw_16831/16831_hw/hw2
#   Preparing metadata (setup.py) ... done
# Installing collected packages: rob831
#   Running setup.py develop for rob831
# Successfully installed rob831-0.1.0

# %%
# downloads mujoco from source
# !wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# !tar xzvf mujoco210-linux-x86_64.tar.gz
# !mkdir -p ~/.mujoco
# !mv mujoco210 ~/.mujoco/mujoco210
# !rm mujoco*

# %pip install -U mujoco
# %pip install -U 'mujoco-py<2.2,>=2.1'
# %pip install -U pyvirtualdisplay
# %pip install -U gym-notebook-wrapper
# %pip install -U "cython<3"

# !cp /root/.mujoco/mujoco210/bin/*.so /usr/lib/x86_64-linux-gnu/
# Out:
# --2026-02-20 01:34:53--  https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Resolving mujoco.org (mujoco.org)... 216.239.32.21, 216.239.38.21, 216.239.34.21, ...
# Connecting to mujoco.org (mujoco.org)|216.239.32.21|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz [following]
# --2026-02-20 01:34:53--  https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-20T02%3A34%3A46Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-20T01%3A34%3A23Z&ske=2026-02-20T02%3A34%3A46Z&sks=b&skv=2018-11-09&sig=hp4scs3e9f6Yl%2F7Uz%2FytNjOFBhu2OS8wI%2FhgjPdd3FY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MTU1MTU5NCwibmJmIjoxNzcxNTUxMjk0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sRUTxVaXBfwuUWz4S-zeOdXBytYpTDvVx4D6E_Y6spo&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-02-20 01:34:54--  https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-20T02%3A34%3A46Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-20T01%3A34%3A23Z&ske=2026-02-20T02%3A34%3A46Z&sks=b&skv=2018-11-09&sig=hp4scs3e9f6Yl%2F7Uz%2FytNjOFBhu2OS8wI%2FhgjPdd3FY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MTU1MTU5NCwibmJmIjoxNzcxNTUxMjk0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sRUTxVaXBfwuUWz4S-zeOdXBytYpTDvVx4D6E_Y6spo&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4385135 (4.2M) [application/octet-stream]
# Saving to: ‘mujoco210-linux-x86_64.tar.gz’
#
# mujoco210-linux-x86 100%[===================>]   4.18M  --.-KB/s    in 0.1s
#
# 2026-02-20 01:34:54 (30.0 MB/s) - ‘mujoco210-linux-x86_64.tar.gz’ saved [4385135/4385135]
#
# mujoco210/
# mujoco210/THIRD_PARTY_NOTICES
# mujoco210/bin/
# mujoco210/bin/libglfw.so.3
# mujoco210/bin/derivative
# mujoco210/bin/libglew.so
# mujoco210/bin/record
# mujoco210/bin/simulate
# mujoco210/bin/libglewegl.so
# mujoco210/bin/testxml
# mujoco210/bin/basic
# mujoco210/bin/libglewosmesa.so
# mujoco210/bin/libglfw3.a
# mujoco210/bin/libmujoco210.so
# mujoco210/bin/compile
# mujoco210/bin/libmujoco210nogl.so
# mujoco210/bin/testspeed
# mujoco210/include/
# mujoco210/include/glfw3.h
# mujoco210/include/uitools.c
# mujoco210/include/mjxmacro.h
# mujoco210/include/mjui.h
# mujoco210/include/mjrender.h
# mujoco210/include/mjmodel.h
# mujoco210/include/mjdata.h
# mujoco210/include/mujoco.h
# mujoco210/include/mjvisualize.h
# mujoco210/include/uitools.h
# mujoco210/model/
# mujoco210/model/humanoid100.xml
# mujoco210/model/arm26.xml
# mujoco210/model/carpet.png
# mujoco210/model/softbox.xml
# mujoco210/model/grid2pin.xml
# mujoco210/model/sponge.png
# mujoco210/model/hammock.xml
# mujoco210/model/cloth.xml
# mujoco210/model/grid2.xml
# mujoco210/model/grid1.xml
# mujoco210/model/grid1pin.xml
# mujoco210/model/softellipsoid.xml
# mujoco210/model/softcylinder.xml
# mujoco210/model/marble.png
# mujoco210/model/rope.xml
# mujoco210/model/particle.xml
# mujoco210/model/loop.xml
# mujoco210/model/humanoid.xml
# mujoco210/model/scene.xml
# mujoco210/sample/
# mujoco210/sample/derivative.cc
# mujoco210/sample/testspeed.cc
# mujoco210/sample/Makefile
# mujoco210/sample/basic.cc
# mujoco210/sample/record.cc
# mujoco210/sample/compile.cc
# mujoco210/sample/simulate.cc
# mujoco210/sample/testxml.cc
# Collecting mujoco
#   Downloading mujoco-3.5.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco) (1.12.2)
# Collecting glfw (from mujoco)
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mujoco) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco) (3.1.9)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco) (4.14.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco) (3.23.0)
# Downloading mujoco-3.5.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 74.6 MB/s eta 0:00:00
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 38.6 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.10.0 mujoco-3.5.0
# Collecting mujoco-py<2.2,>=2.1
#   Downloading mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1) (2.10.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1) (2.0.2)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1) (3.0.12)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1) (2.37.0)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1) (1.17.1)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1)
#   Downloading fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1) (2.22)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio>=2.1.2->mujoco-py<2.2,>=2.1) (11.2.1)
# Downloading mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.8 MB/s eta 0:00:00
# Downloading fasteners-0.20-py3-none-any.whl (18 kB)
# Installing collected packages: fasteners, mujoco-py
# Successfully installed fasteners-0.20 mujoco-py-2.1.2.14
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Collecting gym-notebook-wrapper
#   Downloading gym_notebook_wrapper-1.3.3-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (from gym-notebook-wrapper) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from gym-notebook-wrapper) (3.10.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.11/dist-packages (from gym-notebook-wrapper) (3.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from gym-notebook-wrapper) (7.34.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (from gym-notebook-wrapper) (1.0.3)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym->gym-notebook-wrapper) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym->gym-notebook-wrapper) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym->gym-notebook-wrapper) (0.0.8)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (75.2.0)
# Collecting jedi>=0.16 (from ipython->gym-notebook-wrapper)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->gym-notebook-wrapper) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gym-notebook-wrapper) (2.9.0.post0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy->gym-notebook-wrapper) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy->gym-notebook-wrapper) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->gym-notebook-wrapper) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy->gym-notebook-wrapper) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->gym-notebook-wrapper) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->gym-notebook-wrapper) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->gym-notebook-wrapper) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->gym-notebook-wrapper) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->gym-notebook-wrapper) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2025.7.14)
# Downloading gym_notebook_wrapper-1.3.3-py3-none-any.whl (9.9 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.6 MB/s eta 0:00:00
# Installing collected packages: jedi, gym-notebook-wrapper
# Successfully installed gym-notebook-wrapper-1.3.3 jedi-0.19.2
# Collecting cython<3
#   Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.5 MB/s eta 0:00:00
# Installing collected packages: cython
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
# Successfully installed cython-0.29.37

# %%
# set env variables
import os
os.environ['LD_LIBRARY_PATH'] += ':/root/.mujoco/mujoco210/bin'
os.environ['MUJOCO_PY_MUJOCO_PATH'] = '/root/.mujoco/mujoco210'
os.environ['LD_LIBRARY_PATH'] += ':/usr/lib/nvidia'

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import gym
import gnwrapper

import numpy as np
if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

env = gnwrapper.LoopAnimation(gym.make('Ant-v4'))

observation = env.reset()
for i in range(100):
    obs, rew, term, _ = env.step(env.action_space.sample())
    env.render()
    if term:
      break

env.display()
env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/Cython/Distutils/old_build_ext.py:15: DeprecationWarning: dep_util is Deprecated. Use functions from setuptools instead.
#   from distutils.dep_util import newer, newer_group
# Compiling /usr/local/lib/python3.11/dist-packages/mujoco_py/cymj.pyx because it changed.
# [1/1] Cythonizing /usr/local/lib/python3.11/dist-packages/mujoco_py/cymj.pyx
# INFO:root:running build_ext
# INFO:root:building 'mujoco_py.cymj' extension
# INFO:root:creating /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py
# INFO:root:creating /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py/gl
# INFO:root:x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/mujoco_py -I/root/.mujoco/mujoco210/include -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -c /usr/local/lib/python3.11/dist-packages/mujoco_py/cymj.c -o /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py/cymj.o -fopenmp -w
# INFO:root:x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/mujoco_py -I/root/.mujoco/mujoco210/include -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -c /usr/local/lib/python3.11/dist-packages/mujoco_py/gl/osmesashim.c -o /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py/gl/osmesashim.o -fopenmp -w
# INFO:root:creating /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-311/mujoco_py
# INFO:root:x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py/cymj.o /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-311/usr/local/lib/python3.11/dist-packages/mujoco_py/gl/osmesashim.o -L/root/.mujoco/mujoco210/bin -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-rpath,/root/.mujoco/mujoco210/bin -lmujoco210 -lglewosmesa -lOSMesa -lGL -o /usr/local/lib/python3.11/dist-packages/mujoco_py/generated/_pyxbld_2.1.2.14_311_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-311/mujoco_py/cymj.cpython-311-x86_64-linux-gnu.so -fopenmp
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.HTMLWriter'>
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcc6fbe5a44a2478287dca678a16c0882">
#   <div class="anim-controls">
#     <input id="_anim_slidercc6fbe5a44a2478287dca678a16c0882" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcc6fbe5a44a2478287dca678a16c0882.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcc6fbe5a44a2478287dca678a16c0882.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcc6fbe5a44a2478287dca678a16c0882.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcc6fbe5a44a2478287dca678a16c0882.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcc6fbe5a44a2478287dca678a16c0882.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcc6fbe5a44a2478287dca678a16c0882.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcc6fbe5a44a2478287dca678a16c0882.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcc6fbe5a44a2478287dca678a16c0882.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcc6fbe5a44a2478287dca678a16c0882.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcc6fbe5a44a2478287dca678a16c0882.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcc6fbe5a44a2478287dca678a16c0882"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cc6fbe5a44a2478287dca678a16c0882"
#              >
#       <label for="_anim_radio1_cc6fbe5a44a2478287dca678a16c0882">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cc6fbe5a44a2478287dca678a16c0882"
#              checked>
#       <label for="_anim_radio2_cc6fbe5a44a2478287dca678a16c0882">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cc6fbe5a44a2478287dca678a16c0882"
#              >
#       <label for="_anim_radio3_cc6fbe5a44a2478287dca678a16c0882">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcc6fbe5a44a2478287dca678a16c0882";
#     var slider_id = "_anim_slidercc6fbe5a44a2478287dca678a16c0882";
#     var loop_select_id = "_anim_loop_selectcc6fbe5a44a2478287dca678a16c0882";
#     var frames = new Array(28);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAL\
# EwAACxMBAJqcGAAA0M5JR

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`hw_16831/...`). Double click a file to open an editor. There is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.

# %% [markdown]
# ## Run Policy Gradients

# %%
# !pip install imp
# !git pull
# Out:
# ERROR: Could not find a version that satisfies the requirement imp (from versions: none)
# ERROR: No matching distribution found for imp

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.4

# %%
#@title imports

import os
import time

from rob831.infrastructure.rl_trainer import RL_Trainer
from rob831.agents.pg_agent import PGAgent

# %load_ext autoreload
# %autoreload 2

# %%
#@title runtime arguments
from dataclasses import dataclass

@dataclass
class Args:
  env_name = 'CartPole-v0' #@param
  exp_name = 'q1_sb_no_rtg_dsa' #@param

  #@markdown main parameters of interest
  n_iter = 100 #@param {type: "integer"}

  ## PDF will tell you how to set ep_len
  ## and discount for each environment
  ep_len = 200 #@param {type: "integer"}
  discount = 0.95 #@param {type: "number"}

  reward_to_go = False #@param {type: "boolean"}
  nn_baseline = False #@param {type: "boolean"}
  gae_lambda = None #@param {type: "number"}
  dont_standardize_advantages = True #@param {type: "boolean"}

  #@markdown batches and steps
  batch_size = 1000 #@param {type: "integer"}
  eval_batch_size = 400 #@param {type: "integer"}

  num_agent_train_steps_per_iter = 1 #@param {type: "integer"}
  learning_rate =  5e-3 #@param {type: "number"}

  #@markdown MLP parameters
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}

  #@markdown system
  save_params = False #@param {type: "boolean"}
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}

  action_noise_std = 0 #@param {type: "number"}

  #@markdown logging
  ## default is to not log video so
  ## that logs are small enough to be
  ## uploaded to gradscope
  video_log_freq =  -1#@param {type: "integer"}
  scalar_log_freq =  1#@param {type: "integer"}

  n_workers = 1 #@param {type: "integer"}

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  def __contains__(self, key):
    return hasattr(self, key)

  def get(self, key, default=None):
    return getattr(self, key, default)

args = Args()

## ensure compatibility with hw1 code
args['train_batch_size'] = args['batch_size']

if args['video_log_freq'] > 0:
  import warnings
  warnings.warn(
      '''\nLogging videos will make eventfiles too'''
      '''\nlarge for the autograder. Set video_log_freq = -1'''
      '''\nfor the runs you intend to submit.''')

# %%
from dataclasses import dataclass

@dataclass
class Args:
  env_name: str = 'CartPole-v0'
  exp_name: str = 'q1_sb_no_rtg_dsa'

  n_iter: int = 100

  ## PDF will tell you how to set ep_len
  ## and discount for each environment
  ep_len: int = 200
  discount: int = 0.95

  reward_to_go: bool = False
  nn_baseline: bool = False
  gae_lambda: float = None
  dont_standardize_advantages: bool = True

  batch_size: int = 1000
  eval_batch_size: int = 400

  num_agent_train_steps_per_iter: int = 1
  learning_rate: float =  5e-3

  n_layers: int = 2
  size: int = 64

  save_params: bool = False
  no_gpu: bool = False
  which_gpu: int = 0
  seed: int = 1

  action_noise_std: int = 0

  ## default is to not log video so
  ## that logs are small enough to be
  ## uploaded to gradscope
  video_log_freq: int =  -1
  scalar_log_freq: int =  1

  n_workers: int = 1

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  def __contains__(self, key):
    return hasattr(self, key)

  def get(self, key, default=None):
    return getattr(self, key, default)

  def __post_init__(self):
    self.train_batch_size = self.batch_size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-12-3016029538.py in <cell line: 0>()
# ----> 1 @dataclass
#       2 class Args:
#       3   env_name: str = 'CartPole-v0'
#       4   exp_name: str = 'q1_sb_no_rtg_dsa'
#       5
#
# NameError: name 'dataclass' is not defined

# %%
configs_q1 = [
    Args(env_name='CartPole-v0', exp_name='q1_sb_no_rtg_dsa', n_iter=100, batch_size=1000, dont_standardize_advantages=True, reward_to_go=False),
    Args(env_name='CartPole-v0', exp_name='q1_sb_rtg_dsa', n_iter=100, batch_size=1000, dont_standardize_advantages=True, reward_to_go=True),
    Args(env_name='CartPole-v0', exp_name='q1_sb_rtg_na', n_iter=100, batch_size=1000, dont_standardize_advantages=False, reward_to_go=True),
    Args(env_name='CartPole-v0', exp_name='q1_lb_no_rtg_dsa', n_iter=100, batch_size=5000, dont_standardize_advantages=True, reward_to_go=False),
    Args(env_name='CartPole-v0', exp_name='q1_lb_rtg_dsa', n_iter=100, batch_size=5000, dont_standardize_advantages=True, reward_to_go=True),
    Args(env_name='CartPole-v0', exp_name='q1_lb_rtg_na', n_iter=100, batch_size=5000, dont_standardize_advantages=False, reward_to_go=True),
]

# %%
from functools import partial
q2_batch_sizes = [100, 100, 300, 300]
q2_learning_rates = [1e-2, 5e-3, 1e-2, 5e-2]
q2_partial = partial(Args, env_name='InvertedPendulum-v4', ep_len=100, discount=0.9, n_iter=100, n_layers=2, size=64, reward_to_go=True)
configs_q2 = []
for batch_size, learning_rate in zip(q2_batch_sizes, q2_learning_rates):
  # Set batch size, learning rate and env_name q2_b<b*>_r<r*>
  configs_q2.append(q2_partial(batch_size=batch_size, learning_rate=learning_rate, exp_name=f'q2_b{batch_size}_r{learning_rate}'))

# %%
#@title create directory for logging

data_path = '''/content/hw_16831/hw2/data'''

if not (os.path.exists(data_path)):
    os.makedirs(data_path)

# logdir = args.exp_name + '_' + args.env_name + '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
# logdir = os.path.join(data_path, logdir)
# args['logdir'] = logdir
# if not(os.path.exists(logdir)):
#     os.makedirs(logdir)

# %%
## define policy gradient trainer

class PG_Trainer(object):

    def __init__(self, params):

        #####################
        ## SET AGENT PARAMS
        #####################

        computation_graph_args = {
            'n_layers': params['n_layers'],
            'size': params['size'],
            'learning_rate': params['learning_rate'],
            }

        estimate_advantage_args = {
            'gamma': params['discount'],
            'standardize_advantages': not(params['dont_standardize_advantages']),
            'reward_to_go': params['reward_to_go'],
            'nn_baseline': params['nn_baseline'],
            'gae_lambda': params['gae_lambda'],
        }

        train_args = {
            'num_agent_train_steps_per_iter': params['num_agent_train_steps_per_iter'],
        }

        agent_params = {**computation_graph_args, **estimate_advantage_args, **train_args}

        self.params = params
        self.params['agent_class'] = PGAgent
        self.params['agent_params'] = agent_params
        self.params['batch_size_initial'] = self.params['batch_size']

        ################
        ## RL TRAINER
        ################

        self.rl_trainer = RL_Trainer(self.params)

    def run_training_loop(self):

        self.rl_trainer.run_training_loop(
            self.params['n_iter'],
            collect_policy = self.rl_trainer.agent.actor,
            eval_policy = self.rl_trainer.agent.actor,
            )

# %%
for args in configs_q1:
  logdir = args.exp_name + '_' + args.env_name
  logdir = os.path.join(data_path, logdir)
  args['logdir'] = logdir
  if not(os.path.exists(logdir)):
      os.makedirs(logdir)

  print(args.logdir)
  trainer = PG_Trainer(args)
  trainer.run_training_loop()
# Out:
# /content/hw_16831/hw2/data/q1_sb_no_rtg_dsa_CartPole-v0
# ########################
# logging outputs to  /content/hw_16831/hw2/data/q1_sb_no_rtg_dsa_CartPole-v0
# ########################
# Using GPU id 0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 16.239999771118164
# Eval_StdReturn : 6.488636493682861
# Eval_MaxReturn : 39.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 16.24
# Train_AverageReturn : 20.73469352722168
# Train_StdReturn : 8.10586929321289
# Train_MaxReturn : 43.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 20.73469387755102
# Train_EnvstepsSoFar : 1016
# TimeSinceStart : 1.2114965915679932
# Training Loss : 9.400769233703613
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 19.909090042114258
# Eval_StdReturn : 12.413003921508789
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 19.90909090909091
# Train_AverageReturn : 18.327272415161133
# Train_StdReturn : 11.155193328857422
# Train_MaxReturn : 81.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 18.327272727272728
# Train_EnvstepsSoFar : 2024
# TimeSinceStart : 2.438488245010376
# Training Loss : 8.696283340454102
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 18.545454025268555
# Eval_StdReturn : 9.084088325500488
# Eval_MaxReturn : 42.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 18.545454545454547
# Train_AverageReturn : 15.227272987365723
# Train_StdReturn : 5.840806484222412
# Train_MaxReturn : 34.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 15.227272727272727
# Train_EnvstepsSoFar : 3029
# TimeSinceStart : 3.618182897567749
# Training Loss : 7.476504802703857
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 16.70833396911621
# Eval_StdReturn : 6.7606658935546875
# Eval_MaxReturn : 33.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 16.708333333333332
# Train_AverageReturn : 15.765625
# Train_StdReturn : 6.417120933532715
# Train_MaxReturn : 40.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 15.765625
# Train_EnvstepsSoFar : 4038
# TimeSinceStart : 5.118252992630005
# Training Loss : 7.5128397941589355
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 19.4761905670166
# Eval_StdReturn : 8.203478813171387
# Eval_MaxReturn : 39.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 19.476190476190474
# Train_AverageReturn : 15.415384292602539
# Train_StdReturn : 5.454405307769775
# Train_MaxReturn : 36.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 15.415384615384616
# Train_EnvstepsSoFar : 5040
# TimeSinceStart : 6.741511106491089
# Training Loss : 7.321450710296631
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 15.185185432434082
# Eval_StdReturn : 7.493390083312988
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 15.185185185185185
# Train_AverageReturn : 16.721311569213867
# Train_StdReturn : 8.894889831542969
# Train_MaxReturn : 55.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 16.721311475409838
# Train_EnvstepsSoFar : 6060
# TimeSinceStart : 8.079512596130371
# Training Loss : 8.04052448272705
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 16.83333396911621
# Eval_StdReturn : 5.542762756347656
# Eval_MaxReturn : 33.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 16.833333333333332
# Train_AverageReturn : 17.413793563842773
# Train_StdReturn : 9.386406898498535
# Train_MaxReturn : 57.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 17.413793103448278
# Train_EnvstepsSoFar : 7070
# TimeSinceStart : 9.256490707397461
# Training Loss : 8.413230895996094
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 24.58823585510254
# Eval_StdReturn : 11.555791854858398
# Eval_MaxReturn : 56.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 24.58823529411765
# Train_AverageReturn : 18.160715103149414
# Train_StdReturn : 6.619173526763916
# Train_MaxReturn : 40.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 18.160714285714285
# Train_EnvstepsSoFar : 8087
# TimeSinceStart : 10.516642570495605
# Training Loss : 8.57654094696045
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 23.941177368164062
# Eval_StdReturn : 16.839975357055664
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 23.941176470588236
# Train_AverageReturn : 18.90566062927246
# Train_StdReturn : 8.217019081115723
# Train_MaxReturn : 43.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 18.90566037735849
# Train_EnvstepsSoFar : 9089
# TimeSinceStart : 11.688588857650757
# Training Loss : 8.900845527648926
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 28.785715103149414
# Eval_StdReturn : 17.79718589782715
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 28.785714285714285
# Train_AverageReturn : 20.97916603088379
# Train_StdReturn : 9.054210662841797
# Train_MaxReturn : 56.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 20.979166666666668
# Train_EnvstepsSoFar : 10096
# TimeSinceStart : 12.889445066452026
# Training Loss : 9.451904296875
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 30.0
# Eval_StdReturn : 15.666160583496094
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 30.0
# Train_AverageReturn : 24.16666603088379
# Train_StdReturn : 13.348652839660645
# Train_MaxReturn : 72.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 24.166666666666668
# Train_EnvstepsSoFar : 11111
# TimeSinceStart : 14.095012664794922
# Training Loss : 10.186212539672852
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 28.66666603088379
# Eval_StdReturn : 11.025223731994629
# Eval_MaxReturn : 56.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 28.666666666666668
# Train_AverageReturn : 28.97142791748047
# Train_StdReturn : 16.203149795532227
# Train_MaxReturn : 98.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 28.97142857142857
# Train_EnvstepsSoFar : 12125
# TimeSinceStart : 15.329122543334961
# Training Loss : 10.665711402893066
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 35.08333206176758
# Eval_StdReturn : 16.982629776000977
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 35.083333333333336
# Train_AverageReturn : 35.82758712768555
# Train_StdReturn : 28.00747299194336
# Train_MaxReturn : 157.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 35.827586206896555
# Train_EnvstepsSoFar : 13164
# TimeSinceStart : 16.556435346603394
# Training Loss : 11.361478805541992
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 34.25
# Eval_StdReturn : 13.417183876037598
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 34.25
# Train_AverageReturn : 33.400001525878906
# Train_StdReturn : 17.259973526000977
# Train_MaxReturn : 80.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 33.4
# Train_EnvstepsSoFar : 14166
# TimeSinceStart : 17.996895790100098
# Training Loss : 11.026423454284668
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 50.0
# Eval_StdReturn : 22.135944366455078
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 50.0
# Train_AverageReturn : 39.30769348144531
# Train_StdReturn : 23.366262435913086
# Train_MaxReturn : 114.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 39.30769230769231
# Train_EnvstepsSoFar : 15188
# TimeSinceStart : 19.572486877441406
# Training Loss : 11.34676742553711
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 51.625
# Eval_StdReturn : 20.444665908813477
# Eval_MaxReturn : 95.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 51.625
# Train_AverageReturn : 40.2400016784668
# Train_StdReturn : 19.401607513427734
# Train_MaxReturn : 106.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 40.24
# Train_EnvstepsSoFar : 16194
# TimeSinceStart : 21.00713801383972
# Training Loss : 11.287946701049805
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 46.66666793823242
# Eval_StdReturn : 20.253944396972656
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 46.666666666666664
# Train_AverageReturn : 47.681819915771484
# Train_StdReturn : 20.014509201049805
# Train_MaxReturn : 94.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 47.68181818181818
# Train_EnvstepsSoFar : 17243
# TimeSinceStart : 22.248217821121216
# Training Loss : 11.363359451293945
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 33.91666793823242
# Eval_StdReturn : 15.046917915344238
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 33.916666666666664
# Train_AverageReturn : 42.54166793823242
# Train_StdReturn : 24.984960556030273
# Train_MaxReturn : 112.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 42.541666666666664
# Train_EnvstepsSoFar : 18264
# TimeSinceStart : 23.431163549423218
# Training Loss : 11.099006652832031
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 36.6363639831543
# Eval_StdReturn : 12.86484146118164
# Eval_MaxReturn : 56.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 36.63636363636363
# Train_AverageReturn : 41.279998779296875
# Train_StdReturn : 15.573104858398438
# Train_MaxReturn : 81.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 41.28
# Train_EnvstepsSoFar : 19296
# TimeSinceStart : 24.742435455322266
# Training Loss : 10.862135887145996
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 38.272727966308594
# Eval_StdReturn : 15.291654586791992
# Eval_MaxReturn : 76.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 38.27272727272727
# Train_AverageReturn : 37.62963104248047
# Train_StdReturn : 23.408052444458008
# Train_MaxReturn : 132.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 37.629629629629626
# Train_EnvstepsSoFar : 20312
# TimeSinceStart : 25.9517605304718
# Training Loss : 10.280600547790527
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 29.071428298950195
# Eval_StdReturn : 9.77945613861084
# Eval_MaxReturn : 54.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 29.071428571428573
# Train_AverageReturn : 35.482757568359375
# Train_StdReturn : 17.03671646118164
# Train_MaxReturn : 94.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 35.48275862068966
# Train_EnvstepsSoFar : 21341
# TimeSinceStart : 27.1573646068573
# Training Loss : 10.03860092163086
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 47.55555725097656
# Eval_StdReturn : 22.336374282836914
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 47.55555555555556
# Train_AverageReturn : 33.900001525878906
# Train_StdReturn : 14.19941234588623
# Train_MaxReturn : 69.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 33.9
# Train_EnvstepsSoFar : 22358
# TimeSinceStart : 28.349510192871094
# Training Loss : 9.754331588745117
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 30.846153259277344
# Eval_StdReturn : 6.322684288024902
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 30.846153846153847
# Train_AverageReturn : 38.730770111083984
# Train_StdReturn : 17.259462356567383
# Train_MaxReturn : 88.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 38.73076923076923
# Train_EnvstepsSoFar : 23365
# TimeSinceStart : 29.537392377853394
# Training Loss : 10.143001556396484
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 36.90909194946289
# Eval_StdReturn : 11.634232521057129
# Eval_MaxReturn : 59.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 36.90909090909091
# Train_AverageReturn : 41.83333206176758
# Train_StdReturn : 22.70401382446289
# Train_MaxReturn : 124.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 41.833333333333336
# Train_EnvstepsSoFar : 24369
# TimeSinceStart : 30.94092607498169
# Training Loss : 10.073731422424316
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 48.099998474121094
# Eval_StdReturn : 20.290145874023438
# Eval_MaxReturn : 85.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 48.1
# Train_AverageReturn : 44.043479919433594
# Train_StdReturn : 18.613876342773438
# Train_MaxReturn : 91.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 44.04347826086956
# Train_EnvstepsSoFar : 25382
# TimeSinceStart : 32.586395263671875
# Training Loss : 10.36130142211914
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 73.33333587646484
# Eval_StdReturn : 48.31378936767578
# Eval_MaxReturn : 177.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 73.33333333333333
# Train_AverageReturn : 56.421051025390625
# Train_StdReturn : 23.313236236572266
# Train_MaxReturn : 111.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 56.421052631578945
# Train_EnvstepsSoFar : 26454
# TimeSinceStart : 34.0681312084198
# Training Loss : 10.41555118560791
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 60.5
# Eval_StdReturn : 28.552583694458008
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 60.5
# Train_AverageReturn : 61.0
# Train_StdReturn : 35.73824691772461
# Train_MaxReturn : 184.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 61.0
# Train_EnvstepsSoFar : 27552
# TimeSinceStart : 35.40183877944946
# Training Loss : 10.482632637023926
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 53.375
# Eval_StdReturn : 13.701619148254395
# Eval_MaxReturn : 85.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 53.375
# Train_AverageReturn : 50.099998474121094
# Train_StdReturn : 15.195063591003418
# Train_MaxReturn : 91.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 50.1
# Train_EnvstepsSoFar : 28554
# TimeSinceStart : 36.605555057525635
# Training Loss : 10.120748519897461
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 57.85714340209961
# Eval_StdReturn : 13.324827194213867
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 57.857142857142854
# Train_AverageReturn : 60.17647171020508
# Train_StdReturn : 35.27077865600586
# Train_MaxReturn : 148.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 60.1764705882353
# Train_EnvstepsSoFar : 29577
# TimeSinceStart : 37.80124568939209
# Training Loss : 10.207286834716797
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 53.25
# Eval_StdReturn : 28.41544532775879
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 53.25
# Train_AverageReturn : 56.11111068725586
# Train_StdReturn : 23.75777816772461
# Train_MaxReturn : 128.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 56.111111111111114
# Train_EnvstepsSoFar : 30587
# TimeSinceStart : 39.02110576629639
# Training Loss : 10.08250904083252
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 50.375
# Eval_StdReturn : 13.133330345153809
# Eval_MaxReturn : 70.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 50.375
# Train_AverageReturn : 68.19999694824219
# Train_StdReturn : 39.871795654296875
# Train_MaxReturn : 159.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 68.2
# Train_EnvstepsSoFar : 31610
# TimeSinceStart : 40.2320511341095
# Training Loss : 9.855013847351074
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 58.0
# Eval_StdReturn : 22.219682693481445
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 58.0
# Train_AverageReturn : 71.66666412353516
# Train_StdReturn : 33.2037467956543
# Train_MaxReturn : 151.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 71.66666666666667
# Train_EnvstepsSoFar : 32685
# TimeSinceStart : 41.52964663505554
# Training Loss : 9.859980583190918
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 58.125
# Eval_StdReturn : 8.63767147064209
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 46.0
# Eval_AverageEpLen : 58.125
# Train_AverageReturn : 68.26667022705078
# Train_StdReturn : 30.516590118408203
# Train_MaxReturn : 157.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 68.26666666666667
# Train_EnvstepsSoFar : 33709
# TimeSinceStart : 42.8065390586853
# Training Loss : 10.023033142089844
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 57.5
# Eval_StdReturn : 18.821529388427734
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 57.5
# Train_AverageReturn : 65.05882263183594
# Train_StdReturn : 27.809162139892578
# Train_MaxReturn : 148.0
# Train_MinReturn : 35.0
# Train_AverageEpLen : 65.05882352941177
# Train_EnvstepsSoFar : 34815
# TimeSinceStart : 44.43909788131714
# Training Loss : 9.744900703430176
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 66.71428680419922
# Eval_StdReturn : 19.89769744873047
# Eval_MaxReturn : 109.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 66.71428571428571
# Train_AverageReturn : 67.73332977294922
# Train_StdReturn : 29.3404541015625
# Train_MaxReturn : 155.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 67.73333333333333
# Train_EnvstepsSoFar : 35831
# TimeSinceStart : 46.11185431480408
# Training Loss : 9.4337797164917
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 72.5
# Eval_StdReturn : 16.790374755859375
# Eval_MaxReturn : 102.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 72.5
# Train_AverageReturn : 73.85713958740234
# Train_StdReturn : 25.53109359741211
# Train_MaxReturn : 152.0
# Train_MinReturn : 53.0
# Train_AverageEpLen : 73.85714285714286
# Train_EnvstepsSoFar : 36865
# TimeSinceStart : 47.43933129310608
# Training Loss : 9.5419921875
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 78.16666412353516
# Eval_StdReturn : 12.889487266540527
# Eval_MaxReturn : 92.0
# Eval_MinReturn : 57.0
# Eval_AverageEpLen : 78.16666666666667
# Train_AverageReturn : 74.06666564941406
# Train_StdReturn : 30.571155548095703
# Train_MaxReturn : 141.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 74.06666666666666
# Train_EnvstepsSoFar : 37976
# TimeSinceStart : 48.76494002342224
# Training Loss : 9.578534126281738
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 68.83333587646484
# Eval_StdReturn : 12.088791847229004
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 54.0
# Eval_AverageEpLen : 68.83333333333333
# Train_AverageReturn : 71.80000305175781
# Train_StdReturn : 24.46276092529297
# Train_MaxReturn : 119.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 71.8
# Train_EnvstepsSoFar : 39053
# TimeSinceStart : 50.04638719558716
# Training Loss : 8.988590240478516
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 87.5999984741211
# Eval_StdReturn : 41.50469970703125
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 87.6
# Train_AverageReturn : 60.882354736328125
# Train_StdReturn : 19.905311584472656
# Train_MaxReturn : 127.0
# Train_MinReturn : 35.0
# Train_AverageEpLen : 60.88235294117647
# Train_EnvstepsSoFar : 40088
# TimeSinceStart : 51.314812898635864
# Training Loss : 8.755236625671387
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 57.14285659790039
# Eval_StdReturn : 19.02200698852539
# Eval_MaxReturn : 87.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 57.142857142857146
# Train_AverageReturn : 72.35713958740234
# Train_StdReturn : 24.531635284423828
# Train_MaxReturn : 146.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 72.35714285714286
# Train_EnvstepsSoFar : 41101
# TimeSinceStart : 52.52232313156128
# Training Loss : 8.947318077087402
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 73.0
# Eval_StdReturn : 19.89137077331543
# Eval_MaxReturn : 97.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 73.0
# Train_AverageReturn : 65.5
# Train_StdReturn : 23.449413299560547
# Train_MaxReturn : 111.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 65.5
# Train_EnvstepsSoFar : 42149
# TimeSinceStart : 53.78040027618408
# Training Loss : 8.948974609375
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 80.19999694824219
# Eval_StdReturn : 26.73125457763672
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 80.2
# Train_AverageReturn : 60.117645263671875
# Train_StdReturn : 21.196231842041016
# Train_MaxReturn : 117.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 60.11764705882353
# Train_EnvstepsSoFar : 43171
# TimeSinceStart : 55.002236127853394
# Training Loss : 7.93223762512207
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 70.33333587646484
# Eval_StdReturn : 17.857460021972656
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 70.33333333333333
# Train_AverageReturn : 58.33333206176758
# Train_StdReturn : 19.13983726501465
# Train_MaxReturn : 114.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 58.333333333333336
# Train_EnvstepsSoFar : 44221
# TimeSinceStart : 56.27220869064331
# Training Loss : 8.216249465942383
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 82.33333587646484
# Eval_StdReturn : 37.01651382446289
# Eval_MaxReturn : 153.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 82.33333333333333
# Train_AverageReturn : 71.33333587646484
# Train_StdReturn : 23.533428192138672
# Train_MaxReturn : 118.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 71.33333333333333
# Train_EnvstepsSoFar : 45291
# TimeSinceStart : 57.99260473251343
# Training Loss : 8.243597030639648
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 78.66666412353516
# Eval_StdReturn : 29.561613082885742
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 78.66666666666667
# Train_AverageReturn : 69.33333587646484
# Train_StdReturn : 20.214405059814453
# Train_MaxReturn : 104.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 69.33333333333333
# Train_EnvstepsSoFar : 46331
# TimeSinceStart : 59.649176359176636
# Training Loss : 8.110116004943848
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 68.66666412353516
# Eval_StdReturn : 34.383460998535156
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 46.0
# Eval_AverageEpLen : 68.66666666666667
# Train_AverageReturn : 58.44444274902344
# Train_StdReturn : 15.70994758605957
# Train_MaxReturn : 97.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 58.44444444444444
# Train_EnvstepsSoFar : 47383
# TimeSinceStart : 60.89303660392761
# Training Loss : 7.497299671173096
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 62.14285659790039
# Eval_StdReturn : 12.21741771697998
# Eval_MaxReturn : 79.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 62.142857142857146
# Train_AverageReturn : 81.38461303710938
# Train_StdReturn : 29.834257125854492
# Train_MaxReturn : 146.0
# Train_MinReturn : 45.0
# Train_AverageEpLen : 81.38461538461539
# Train_EnvstepsSoFar : 48441
# TimeSinceStart : 62.14140009880066
# Training Loss : 7.806053638458252
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 65.0
# Eval_StdReturn : 23.96351432800293
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 65.0
# Train_AverageReturn : 69.19999694824219
# Train_StdReturn : 28.67100715637207
# Train_MaxReturn : 166.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 69.2
# Train_EnvstepsSoFar : 49479
# TimeSinceStart : 63.43877959251404
# Training Loss : 7.722479820251465
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 74.16666412353516
# Eval_StdReturn : 21.782384872436523
# Eval_MaxReturn : 118.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 74.16666666666667
# Train_AverageReturn : 66.66666412353516
# Train_StdReturn : 32.95383834838867
# Train_MaxReturn : 165.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 66.66666666666667
# Train_EnvstepsSoFar : 50479
# TimeSinceStart : 64.67270135879517
# Training Loss : 7.283198356628418
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 55.5
# Eval_StdReturn : 15.48386287689209
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 55.5
# Train_AverageReturn : 62.70588302612305
# Train_StdReturn : 22.341638565063477
# Train_MaxReturn : 122.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 62.705882352941174
# Train_EnvstepsSoFar : 51545
# TimeSinceStart : 65.95658922195435
# Training Loss : 7.272334575653076
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 54.125
# Eval_StdReturn : 20.775211334228516
# Eval_MaxReturn : 101.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 54.125
# Train_AverageReturn : 61.411766052246094
# Train_StdReturn : 25.945777893066406
# Train_MaxReturn : 131.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 61.411764705882355
# Train_EnvstepsSoFar : 52589
# TimeSinceStart : 67.18606352806091
# Training Loss : 7.146703243255615
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 53.375
# Eval_StdReturn : 13.490158081054688
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 53.375
# Train_AverageReturn : 63.125
# Train_StdReturn : 38.3615608215332
# Train_MaxReturn : 181.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 63.125
# Train_EnvstepsSoFar : 53599
# TimeSinceStart : 68.41005873680115
# Training Loss : 6.921477794647217
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 58.0
# Eval_StdReturn : 17.59870147705078
# Eval_MaxReturn : 87.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 58.0
# Train_AverageReturn : 47.6363639831543
# Train_StdReturn : 11.667925834655762
# Train_MaxReturn : 73.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 47.63636363636363
# Train_EnvstepsSoFar : 54647
# TimeSinceStart : 69.7178475856781
# Training Loss : 6.880978107452393
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 45.33333206176758
# Eval_StdReturn : 17.21110725402832
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 45.333333333333336
# Train_AverageReturn : 52.099998474121094
# Train_StdReturn : 16.400915145874023
# Train_MaxReturn : 89.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 52.1
# Train_EnvstepsSoFar : 55689
# TimeSinceStart : 71.33979868888855
# Training Loss : 6.704692840576172
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 38.818180084228516
# Eval_StdReturn : 8.11080265045166
# Eval_MaxReturn : 56.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 38.81818181818182
# Train_AverageReturn : 48.66666793823242
# Train_StdReturn : 17.694049835205078
# Train_MaxReturn : 109.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 48.666666666666664
# Train_EnvstepsSoFar : 56711
# TimeSinceStart : 72.88753843307495
# Training Loss : 6.658688545227051
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 62.71428680419922
# Eval_StdReturn : 47.66164779663086
# Eval_MaxReturn : 176.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 62.714285714285715
# Train_AverageReturn : 60.52941131591797
# Train_StdReturn : 30.519264221191406
# Train_MaxReturn : 147.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 60.529411764705884
# Train_EnvstepsSoFar : 57740
# TimeSinceStart : 74.12585878372192
# Training Loss : 5.985593318939209
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 84.19999694824219
# Eval_StdReturn : 19.843385696411133
# Eval_MaxReturn : 122.0
# Eval_MinReturn : 66.0
# Eval_AverageEpLen : 84.2
# Train_AverageReturn : 56.55555725097656
# Train_StdReturn : 23.257549285888672
# Train_MaxReturn : 112.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 56.55555555555556
# Train_EnvstepsSoFar : 58758
# TimeSinceStart : 75.33236885070801
# Training Loss : 6.456236362457275
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 42.599998474121094
# Eval_StdReturn : 10.091580390930176
# Eval_MaxReturn : 60.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 42.6
# Train_AverageReturn : 48.904762268066406
# Train_StdReturn : 16.87462043762207
# Train_MaxReturn : 92.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 48.904761904761905
# Train_EnvstepsSoFar : 59785
# TimeSinceStart : 76.57628679275513
# Training Loss : 6.123568534851074
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 46.11111068725586
# Eval_StdReturn : 15.652081489562988
# Eval_MaxReturn : 84.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 46.111111111111114
# Train_AverageReturn : 48.42856979370117
# Train_StdReturn : 15.683085441589355
# Train_MaxReturn : 97.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 48.42857142857143
# Train_EnvstepsSoFar : 60802
# TimeSinceStart : 77.76944756507874
# Training Loss : 5.809328556060791
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 36.58333206176758
# Eval_StdReturn : 12.605939865112305
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 36.583333333333336
# Train_AverageReturn : 42.58333206176758
# Train_StdReturn : 16.18877410888672
# Train_MaxReturn : 90.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 42.583333333333336
# Train_EnvstepsSoFar : 61824
# TimeSinceStart : 78.98307943344116
# Training Loss : 6.081576347351074
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 40.20000076293945
# Eval_StdReturn : 24.107261657714844
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 40.2
# Train_AverageReturn : 41.95833206176758
# Train_StdReturn : 20.638717651367188
# Train_MaxReturn : 126.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 41.958333333333336
# Train_EnvstepsSoFar : 62831
# TimeSinceStart : 80.14511442184448
# Training Loss : 6.234118461608887
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 41.70000076293945
# Eval_StdReturn : 13.327040672302246
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 41.7
# Train_AverageReturn : 42.41666793823242
# Train_StdReturn : 14.071001052856445
# Train_MaxReturn : 93.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 42.416666666666664
# Train_EnvstepsSoFar : 63849
# TimeSinceStart : 81.3840503692627
# Training Loss : 5.801464557647705
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 33.83333206176758
# Eval_StdReturn : 7.41432523727417
# Eval_MaxReturn : 47.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 33.833333333333336
# Train_AverageReturn : 37.703704833984375
# Train_StdReturn : 10.25892448425293
# Train_MaxReturn : 62.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 37.7037037037037
# Train_EnvstepsSoFar : 64867
# TimeSinceStart : 82.59907841682434
# Training Loss : 5.722980976104736
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 34.83333206176758
# Eval_StdReturn : 5.580223083496094
# Eval_MaxReturn : 42.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 34.833333333333336
# Train_AverageReturn : 38.51852035522461
# Train_StdReturn : 10.959083557128906
# Train_MaxReturn : 66.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 38.51851851851852
# Train_EnvstepsSoFar : 65907
# TimeSinceStart : 84.2431321144104
# Training Loss : 5.855391025543213
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 34.33333206176758
# Eval_StdReturn : 10.458914756774902
# Eval_MaxReturn : 55.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 34.333333333333336
# Train_AverageReturn : 37.03703689575195
# Train_StdReturn : 6.568620204925537
# Train_MaxReturn : 55.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 37.03703703703704
# Train_EnvstepsSoFar : 66907
# TimeSinceStart : 85.82863330841064
# Training Loss : 5.716271877288818
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 35.08333206176758
# Eval_StdReturn : 8.391050338745117
# Eval_MaxReturn : 55.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 35.083333333333336
# Train_AverageReturn : 38.55555725097656
# Train_StdReturn : 10.008638381958008
# Train_MaxReturn : 62.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 38.55555555555556
# Train_EnvstepsSoFar : 67948
# TimeSinceStart : 87.03810739517212
# Training Loss : 5.833073139190674
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 40.0
# Eval_StdReturn : 11.793681144714355
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 40.0
# Train_AverageReturn : 38.33333206176758
# Train_StdReturn : 7.90686559677124
# Train_MaxReturn : 55.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 38.333333333333336
# Train_EnvstepsSoFar : 68983
# TimeSinceStart : 88.27959752082825
# Training Loss : 6.202223777770996
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 32.846153259277344
# Eval_StdReturn : 5.24545431137085
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 32.84615384615385
# Train_AverageReturn : 33.93333435058594
# Train_StdReturn : 7.809965133666992
# Train_MaxReturn : 55.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 33.93333333333333
# Train_EnvstepsSoFar : 70001
# TimeSinceStart : 89.49999260902405
# Training Loss : 5.615516662597656
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 31.0
# Eval_StdReturn : 5.023024082183838
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 31.0
# Train_AverageReturn : 33.0
# Train_StdReturn : 6.324555397033691
# Train_MaxReturn : 51.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 33.0
# Train_EnvstepsSoFar : 71024
# TimeSinceStart : 90.74327397346497
# Training Loss : 5.550567626953125
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 30.714284896850586
# Eval_StdReturn : 5.2972846031188965
# Eval_MaxReturn : 39.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 30.714285714285715
# Train_AverageReturn : 30.363636016845703
# Train_StdReturn : 7.197719573974609
# Train_MaxReturn : 50.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 30.363636363636363
# Train_EnvstepsSoFar : 72026
# TimeSinceStart : 91.98314547538757
# Training Loss : 5.262233257293701
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 28.85714340209961
# Eval_StdReturn : 5.950476169586182
# Eval_MaxReturn : 44.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 28.857142857142858
# Train_AverageReturn : 30.909090042114258
# Train_StdReturn : 7.191593170166016
# Train_MaxReturn : 44.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 30.90909090909091
# Train_EnvstepsSoFar : 73046
# TimeSinceStart : 93.1914713382721
# Training Loss : 5.402090549468994
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 71 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 31.384614944458008
# Eval_StdReturn : 5.864344120025635
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 31.384615384615383
# Train_AverageReturn : 30.84848403930664
# Train_StdReturn : 6.796260833740234
# Train_MaxReturn : 46.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 30.848484848484848
# Train_EnvstepsSoFar : 74064
# TimeSinceStart : 94.40314364433289
# Training Loss : 5.482626914978027
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 72 ************
#
# Collecting data to be used for training...

# %%
## run training

print(args.logdir)
trainer = PG_Trainer(args)
trainer.run_training_loop()
# Out:
# /content/hw_16831/hw2/data/q1_sb_no_rtg_dsa_CartPole-v0_19-02-2026_22-30-34
# ########################
# logging outputs to  /content/hw_16831/hw2/data/q1_sb_no_rtg_dsa_CartPole-v0_19-02-2026_22-30-34
# ########################
# Using GPU id 0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 29.785715103149414
# Eval_StdReturn : 12.42220687866211
# Eval_MaxReturn : 59.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 29.785714285714285
# Train_AverageReturn : 20.73469352722168
# Train_StdReturn : 8.10586929321289
# Train_MaxReturn : 43.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 20.73469387755102
# Train_EnvstepsSoFar : 1016
# TimeSinceStart : 3.385906457901001
# Training Loss : 5.885738849639893
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 46.11111068725586
# Eval_StdReturn : 30.682764053344727
# Eval_MaxReturn : 110.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 46.111111111111114
# Train_AverageReturn : 32.617645263671875
# Train_StdReturn : 21.409198760986328
# Train_MaxReturn : 117.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 32.61764705882353
# Train_EnvstepsSoFar : 2125
# TimeSinceStart : 4.683433532714844
# Training Loss : 7.763640403747559
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 42.181819915771484
# Eval_StdReturn : 19.474077224731445
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 42.18181818181818
# Train_AverageReturn : 38.14814758300781
# Train_StdReturn : 23.10796546936035
# Train_MaxReturn : 109.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 38.148148148148145
# Train_EnvstepsSoFar : 3155
# TimeSinceStart : 6.047411203384399
# Training Loss : 8.063218116760254
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 46.44444274902344
# Eval_StdReturn : 19.43714141845703
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 46.44444444444444
# Train_AverageReturn : 39.38461685180664
# Train_StdReturn : 20.360363006591797
# Train_MaxReturn : 96.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 39.38461538461539
# Train_EnvstepsSoFar : 4179
# TimeSinceStart : 7.648098707199097
# Training Loss : 7.8709611892700195
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 78.83333587646484
# Eval_StdReturn : 44.11884307861328
# Eval_MaxReturn : 138.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 78.83333333333333
# Train_AverageReturn : 56.44444274902344
# Train_StdReturn : 33.09115982055664
# Train_MaxReturn : 139.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 56.44444444444444
# Train_EnvstepsSoFar : 5195
# TimeSinceStart : 9.329527139663696
# Training Loss : 8.769444465637207
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 50.22222137451172
# Eval_StdReturn : 22.748762130737305
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 50.22222222222222
# Train_AverageReturn : 66.73332977294922
# Train_StdReturn : 26.276647567749023
# Train_MaxReturn : 120.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 66.73333333333333
# Train_EnvstepsSoFar : 6196
# TimeSinceStart : 10.584602355957031
# Training Loss : 8.933804512023926
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 120.75
# Eval_StdReturn : 77.83757019042969
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 120.75
# Train_AverageReturn : 74.0
# Train_StdReturn : 39.61060333251953
# Train_MaxReturn : 166.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 74.0
# Train_EnvstepsSoFar : 7232
# TimeSinceStart : 11.886900186538696
# Training Loss : 9.196858406066895
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 134.3333282470703
# Eval_StdReturn : 34.836124420166016
# Eval_MaxReturn : 179.0
# Eval_MinReturn : 94.0
# Eval_AverageEpLen : 134.33333333333334
# Train_AverageReturn : 91.41666412353516
# Train_StdReturn : 45.33662796020508
# Train_MaxReturn : 200.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 91.41666666666667
# Train_EnvstepsSoFar : 8329
# TimeSinceStart : 13.133808612823486
# Training Loss : 9.377760887145996
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 151.3333282470703
# Eval_StdReturn : 34.65384292602539
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 122.0
# Eval_AverageEpLen : 151.33333333333334
# Train_AverageReturn : 120.0
# Train_StdReturn : 48.908077239990234
# Train_MaxReturn : 200.0
# Train_MinReturn : 46.0
# Train_AverageEpLen : 120.0
# Train_EnvstepsSoFar : 9409
# TimeSinceStart : 14.451080083847046
# Training Loss : 9.880511283874512
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 188.3333282470703
# Eval_StdReturn : 16.499156951904297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 165.0
# Eval_AverageEpLen : 188.33333333333334
# Train_AverageReturn : 160.7142791748047
# Train_StdReturn : 31.842084884643555
# Train_MaxReturn : 200.0
# Train_MinReturn : 115.0
# Train_AverageEpLen : 160.71428571428572
# Train_EnvstepsSoFar : 10534
# TimeSinceStart : 15.914520740509033
# Training Loss : 9.996838569641113
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 141.75
# Eval_StdReturn : 46.33775329589844
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 84.0
# Eval_AverageEpLen : 141.75
# Train_AverageReturn : 167.42857360839844
# Train_StdReturn : 31.613094329833984
# Train_MaxReturn : 200.0
# Train_MinReturn : 122.0
# Train_AverageEpLen : 167.42857142857142
# Train_EnvstepsSoFar : 11706
# TimeSinceStart : 17.38328766822815
# Training Loss : 10.131766319274902
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 157.6666717529297
# Eval_StdReturn : 15.195029258728027
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 138.0
# Eval_AverageEpLen : 157.66666666666666
# Train_AverageReturn : 154.42857360839844
# Train_StdReturn : 53.37430191040039
# Train_MaxReturn : 200.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 154.42857142857142
# Train_EnvstepsSoFar : 12787
# TimeSinceStart : 18.709094524383545
# Training Loss : 9.950244903564453
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 152.0
# Eval_StdReturn : 37.665191650390625
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 108.0
# Eval_AverageEpLen : 152.0
# Train_AverageReturn : 131.0
# Train_StdReturn : 57.969818115234375
# Train_MaxReturn : 200.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 131.0
# Train_EnvstepsSoFar : 13835
# TimeSinceStart : 20.22771382331848
# Training Loss : 9.776265144348145
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 114.75
# Eval_StdReturn : 58.08345413208008
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 114.75
# Train_AverageReturn : 129.55555725097656
# Train_StdReturn : 54.98102951049805
# Train_MaxReturn : 200.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 129.55555555555554
# Train_EnvstepsSoFar : 15001
# TimeSinceStart : 22.06344509124756
# Training Loss : 9.62601089477539
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 128.5
# Eval_StdReturn : 53.115440368652344
# Eval_MaxReturn : 178.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 128.5
# Train_AverageReturn : 129.5
# Train_StdReturn : 38.46426773071289
# Train_MaxReturn : 200.0
# Train_MinReturn : 55.0
# Train_AverageEpLen : 129.5
# Train_EnvstepsSoFar : 16037
# TimeSinceStart : 23.511152505874634
# Training Loss : 9.76645565032959
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 157.3333282470703
# Eval_StdReturn : 12.283684730529785
# Eval_MaxReturn : 167.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 157.33333333333334
# Train_AverageReturn : 127.66666412353516
# Train_StdReturn : 56.9931755065918
# Train_MaxReturn : 200.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 127.66666666666667
# Train_EnvstepsSoFar : 17186
# TimeSinceStart : 24.90381956100464
# Training Loss : 9.802756309509277
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 171.3333282470703
# Eval_StdReturn : 31.794479370117188
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 127.0
# Eval_AverageEpLen : 171.33333333333334
# Train_AverageReturn : 161.42857360839844
# Train_StdReturn : 55.73881912231445
# Train_MaxReturn : 200.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 161.42857142857142
# Train_EnvstepsSoFar : 18316
# TimeSinceStart : 26.30409598350525
# Training Loss : 10.311427116394043
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 180.6666717529297
# Eval_StdReturn : 27.341461181640625
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 142.0
# Eval_AverageEpLen : 180.66666666666666
# Train_AverageReturn : 188.3333282470703
# Train_StdReturn : 18.2817440032959
# Train_MaxReturn : 200.0
# Train_MinReturn : 149.0
# Train_AverageEpLen : 188.33333333333334
# Train_EnvstepsSoFar : 19446
# TimeSinceStart : 27.689037322998047
# Training Loss : 10.303396224975586
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 144.75
# Eval_StdReturn : 42.21596145629883
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 89.0
# Eval_AverageEpLen : 144.75
# Train_AverageReturn : 156.42857360839844
# Train_StdReturn : 47.85948944091797
# Train_MaxReturn : 200.0
# Train_MinReturn : 83.0
# Train_AverageEpLen : 156.42857142857142
# Train_EnvstepsSoFar : 20541
# TimeSinceStart : 29.07987332344055
# Training Loss : 10.174860954284668
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 21541
# TimeSinceStart : 30.232194423675537
# Training Loss : 10.323857307434082
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 193.3333282470703
# Eval_StdReturn : 9.428091049194336
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 180.0
# Eval_AverageEpLen : 193.33333333333334
# Train_AverageReturn : 128.625
# Train_StdReturn : 58.640724182128906
# Train_MaxReturn : 200.0
# Train_MinReturn : 53.0
# Train_AverageEpLen : 128.625
# Train_EnvstepsSoFar : 22570
# TimeSinceStart : 31.608031749725342
# Training Loss : 9.944860458374023
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 189.8333282470703
# Train_StdReturn : 22.73335838317871
# Train_MaxReturn : 200.0
# Train_MinReturn : 139.0
# Train_AverageEpLen : 189.83333333333334
# Train_EnvstepsSoFar : 23709
# TimeSinceStart : 33.11791253089905
# Training Loss : 10.241532325744629
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 117.25
# Eval_StdReturn : 50.74630355834961
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 71.0
# Eval_AverageEpLen : 117.25
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 24709
# TimeSinceStart : 34.686339378356934
# Training Loss : 10.275420188903809
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 159.0
# Eval_StdReturn : 30.735429763793945
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 126.0
# Eval_AverageEpLen : 159.0
# Train_AverageReturn : 179.6666717529297
# Train_StdReturn : 29.448637008666992
# Train_MaxReturn : 200.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 179.66666666666666
# Train_EnvstepsSoFar : 25787
# TimeSinceStart : 36.31193542480469
# Training Loss : 10.297554016113281
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 145.0
# Train_StdReturn : 48.5533561706543
# Train_MaxReturn : 200.0
# Train_MinReturn : 56.0
# Train_AverageEpLen : 145.0
# Train_EnvstepsSoFar : 26802
# TimeSinceStart : 37.517300844192505
# Training Loss : 9.939019203186035
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 155.0
# Eval_StdReturn : 44.72881317138672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 94.0
# Eval_AverageEpLen : 155.0
# Train_AverageReturn : 159.85714721679688
# Train_StdReturn : 46.357086181640625
# Train_MaxReturn : 200.0
# Train_MinReturn : 105.0
# Train_AverageEpLen : 159.85714285714286
# Train_EnvstepsSoFar : 27921
# TimeSinceStart : 38.869009256362915
# Training Loss : 10.16739273071289
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 184.6666717529297
# Eval_StdReturn : 10.964590072631836
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 175.0
# Eval_AverageEpLen : 184.66666666666666
# Train_AverageReturn : 135.125
# Train_StdReturn : 54.18587875366211
# Train_MaxReturn : 200.0
# Train_MinReturn : 48.0
# Train_AverageEpLen : 135.125
# Train_EnvstepsSoFar : 29002
# TimeSinceStart : 40.25177192687988
# Training Loss : 9.981843948364258
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 160.0
# Eval_StdReturn : 56.56854248046875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 80.0
# Eval_AverageEpLen : 160.0
# Train_AverageReturn : 143.0
# Train_StdReturn : 59.353660583496094
# Train_MaxReturn : 200.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 143.0
# Train_EnvstepsSoFar : 30003
# TimeSinceStart : 41.539631605148315
# Training Loss : 9.860738754272461
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 131.5
# Eval_StdReturn : 41.33702850341797
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 131.5
# Train_AverageReturn : 125.125
# Train_StdReturn : 61.58213424682617
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 125.125
# Train_EnvstepsSoFar : 31004
# TimeSinceStart : 42.823784589767456
# Training Loss : 9.796917915344238
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 156.3333282470703
# Eval_StdReturn : 50.86146926879883
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 85.0
# Eval_AverageEpLen : 156.33333333333334
# Train_AverageReturn : 135.75
# Train_StdReturn : 65.4632568359375
# Train_MaxReturn : 200.0
# Train_MinReturn : 50.0
# Train_AverageEpLen : 135.75
# Train_EnvstepsSoFar : 32090
# TimeSinceStart : 44.16705131530762
# Training Loss : 9.994571685791016
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 127.33333587646484
# Train_StdReturn : 45.44593811035156
# Train_MaxReturn : 200.0
# Train_MinReturn : 73.0
# Train_AverageEpLen : 127.33333333333333
# Train_EnvstepsSoFar : 33236
# TimeSinceStart : 45.509467124938965
# Training Loss : 9.742757797241211
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 137.5
# Eval_StdReturn : 64.40690612792969
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 137.5
# Train_AverageReturn : 129.25
# Train_StdReturn : 57.7164421081543
# Train_MaxReturn : 200.0
# Train_MinReturn : 55.0
# Train_AverageEpLen : 129.25
# Train_EnvstepsSoFar : 34270
# TimeSinceStart : 47.58478617668152
# Training Loss : 9.847257614135742
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 144.14285278320312
# Train_StdReturn : 58.89804458618164
# Train_MaxReturn : 200.0
# Train_MinReturn : 59.0
# Train_AverageEpLen : 144.14285714285714
# Train_EnvstepsSoFar : 35279
# TimeSinceStart : 49.53923153877258
# Training Loss : 9.936210632324219
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 111.0
# Eval_StdReturn : 61.68873596191406
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 111.0
# Train_AverageReturn : 112.19999694824219
# Train_StdReturn : 59.307334899902344
# Train_MaxReturn : 200.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 112.2
# Train_EnvstepsSoFar : 36401
# TimeSinceStart : 50.89085793495178
# Training Loss : 9.468636512756348
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 152.0
# Train_StdReturn : 68.09237670898438
# Train_MaxReturn : 200.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 152.0
# Train_EnvstepsSoFar : 37465
# TimeSinceStart : 52.16067576408386
# Training Loss : 9.65594482421875
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 144.25
# Eval_StdReturn : 63.001487731933594
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 144.25
# Train_AverageReturn : 169.42857360839844
# Train_StdReturn : 47.08308029174805
# Train_MaxReturn : 200.0
# Train_MinReturn : 74.0
# Train_AverageEpLen : 169.42857142857142
# Train_EnvstepsSoFar : 38651
# TimeSinceStart : 53.65232253074646
# Training Loss : 10.057768821716309
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 153.2857208251953
# Train_StdReturn : 74.45173645019531
# Train_MaxReturn : 200.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 153.28571428571428
# Train_EnvstepsSoFar : 39724
# TimeSinceStart : 55.08043885231018
# Training Loss : 9.756959915161133
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 40724
# TimeSinceStart : 56.38571286201477
# Training Loss : 10.082352638244629
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 41724
# TimeSinceStart : 57.58730697631836
# Training Loss : 9.94804573059082
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 42724
# TimeSinceStart : 58.763145446777344
# Training Loss : 10.03168773651123
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 43724
# TimeSinceStart : 60.26229810714722
# Training Loss : 9.617859840393066
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 44724
# TimeSinceStart : 61.81301259994507
# Training Loss : 9.428927421569824
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 45724
# TimeSinceStart : 63.443689584732056
# Training Loss : 9.178988456726074
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 46724
# TimeSinceStart : 64.61113929748535
# Training Loss : 9.25162410736084
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 47724
# TimeSinceStart : 66.10462641716003
# Training Loss : 9.100003242492676
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 48724
# TimeSinceStart : 67.28630042076111
# Training Loss : 8.976619720458984
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 49724
# TimeSinceStart : 68.47115659713745
# Training Loss : 8.93696403503418
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 50724
# TimeSinceStart : 69.68255853652954
# Training Loss : 8.722404479980469
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 51724
# TimeSinceStart : 70.92549324035645
# Training Loss : 8.892472267150879
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 52724
# TimeSinceStart : 72.09957766532898
# Training Loss : 8.874744415283203
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 53724
# TimeSinceStart : 73.60620379447937
# Training Loss : 8.620173454284668
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 54724
# TimeSinceStart : 75.1794376373291
# Training Loss : 8.710554122924805
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 55724
# TimeSinceStart : 78.71543836593628
# Training Loss : 8.542121887207031
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 56724
# TimeSinceStart : 79.91820192337036
# Training Loss : 8.311735153198242
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 57724
# TimeSinceStart : 81.54969501495361
# Training Loss : 8.432823181152344
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 58724
# TimeSinceStart : 82.73412084579468
# Training Loss : 8.382609367370605
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 59724
# TimeSinceStart : 83.89395713806152
# Training Loss : 8.337873458862305
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 60724
# TimeSinceStart : 85.0560793876648
# Training Loss : 8.268241882324219
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 61724
# TimeSinceStart : 86.51867914199829
# Training Loss : 8.269681930541992
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 62724
# TimeSinceStart : 88.10031199455261
# Training Loss : 8.527580261230469
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 63724
# TimeSinceStart : 89.4834930896759
# Training Loss : 7.931085109710693
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 64724
# TimeSinceStart : 90.68762254714966
# Training Loss : 8.246013641357422
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 65724
# TimeSinceStart : 91.8748300075531
# Training Loss : 8.095756530761719
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 66724
# TimeSinceStart : 93.06869506835938
# Training Loss : 8.050024032592773
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 67724
# TimeSinceStart : 94.2204601764679
# Training Loss : 7.973474979400635
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 68724
# TimeSinceStart : 95.40339374542236
# Training Loss : 7.839892864227295
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 69724
# TimeSinceStart : 96.61576294898987
# Training Loss : 7.974593639373779
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 70724
# TimeSinceStart : 97.77363562583923
# Training Loss : 7.422570705413818
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# ...
# Train_EnvstepsSoFar : 78724
# TimeSinceStart : 108.11478924751282
# Training Loss : 7.333691596984863
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 76 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 79724
# TimeSinceStart : 109.3293673992157
# Training Loss : 7.2588911056518555
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 80724
# TimeSinceStart : 110.50453424453735
# Training Loss : 7.3851237297058105
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 81724
# TimeSinceStart : 111.69381475448608
# Training Loss : 6.843040943145752
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 82724
# TimeSinceStart : 113.2852954864502
# Training Loss : 6.961122512817383
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 83724
# TimeSinceStart : 114.92617130279541
# Training Loss : 7.366269588470459
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 84724
# TimeSinceStart : 116.14264059066772
# Training Loss : 7.070934772491455
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 85724
# TimeSinceStart : 117.3904390335083
# Training Loss : 6.699665546417236
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 86724
# TimeSinceStart : 118.61138844490051
# Training Loss : 7.189474105834961
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 87724
# TimeSinceStart : 119.8374879360199
# Training Loss : 6.920605182647705
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 88724
# TimeSinceStart : 121.04515433311462
# Training Loss : 6.780755996704102
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 199.6666717529297
# Eval_StdReturn : 0.471404492855072
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 199.0
# Eval_AverageEpLen : 199.66666666666666
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 89724
# TimeSinceStart : 122.3951621055603
# Training Loss : 6.774234771728516
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 90724
# TimeSinceStart : 123.71215081214905
# Training Loss : 6.955236434936523
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 91724
# TimeSinceStart : 124.9103147983551
# Training Loss : 6.473215103149414
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 92724
# TimeSinceStart : 126.50178551673889
# Training Loss : 6.521965980529785
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 93724
# TimeSinceStart : 128.25182509422302
# Training Loss : 6.367403984069824
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 94724
# TimeSinceStart : 129.4871027469635
# Training Loss : 5.960174083709717
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 190.6666717529297
# Eval_StdReturn : 13.199326515197754
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 172.0
# Eval_AverageEpLen : 190.66666666666666
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 95724
# TimeSinceStart : 130.83826208114624
# Training Loss : 5.963790416717529
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 96724
# TimeSinceStart : 132.00721073150635
# Training Loss : 5.927492618560791
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 97724
# TimeSinceStart : 133.17880249023438
# Training Loss : 6.156052589416504
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 98724
# TimeSinceStart : 134.34755563735962
# Training Loss : 6.0607991218566895
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 99724
# TimeSinceStart : 135.56692600250244
# Training Loss : 6.154588222503662
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 100724
# TimeSinceStart : 136.77568888664246
# Training Loss : 5.83355188369751
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 101724
# TimeSinceStart : 137.9768123626709
# Training Loss : 5.820529937744141
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# INFO:tensorboardX.summary:Summary name Training Loss is illegal; using Training_Loss instead.
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 102724
# TimeSinceStart : 139.52655577659607
# Training Loss : 5.860692501068115
# Initial_DataCollection_AverageReturn : 20.73469352722168
# Done logging...

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

def _read_tb_scalars(logdir, tag='Eval_AverageReturn'):
    ea = EventAccumulator(logdir)
    ea.Reload()
    if tag not in ea.Tags().get('scalars', []):
        raise ValueError(f"Tag '{tag}' not in {logdir}. Available: {ea.Tags().get('scalars', [])}")
    events = ea.Scalars(tag)
    return np.array([e.step for e in events]), np.array([e.value for e in events])

def find_logdirs(prefix, data_path='/content/hw_16831/hw2/data'):
    return sorted(glob.glob(os.path.join(data_path, prefix + '*')))

def plot_experiments(logdirs, labels=None, tag='Eval_AverageReturn',
                      title='Learning Curves', xlabel='Iteration',
                      ylabel='Average Return', savepath=None, figsize=(10, 6)):
    expanded = []
    for p in logdirs:
        matches = sorted(glob.glob(p))
        expanded.extend(matches if matches else [p])
    logdirs = expanded

    if labels is None:
        labels = [os.path.basename(d).rsplit('_', 2)[0] for d in logdirs]

    plt.figure(figsize=figsize)
    for logdir, label in zip(logdirs, labels):
        steps, values = _read_tb_scalars(logdir, tag)
        plt.plot(steps, values, label=label)
    plt.xlabel(xlabel); plt.ylabel(ylabel); plt.title(title)
    plt.legend(loc='best'); plt.grid(True, alpha=0.3); plt.tight_layout()
    if savepath:
        plt.savefig(savepath, dpi=150, bbox_inches='tight')
    plt.show()

# Usage after training:
# Q1 example
plot_experiments(find_logdirs('q1_sb_'), title='Q1: CartPole Small Batch (b=1000)', savepath='/content/saves')
# plot_experiments(find_logdirs('q1_lb_'), title='Q1: CartPole Large Batch (b=5000)')
# Out:
# INFO:tensorboard:No path found after /content/hw_16831/hw2/data/q1_sb_no_rtg_dsa_CartPole-v0_19-02-2026_22-30-34/events.out.tfevents.1771540236.1f5bfe7205ff
# /tmp/ipython-input-39-253279508.py:37: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

## requires tensorflow==2.3.0
# %load_ext tensorboard
# %tensorboard --logdir /content/hw_16831/hw2/data
